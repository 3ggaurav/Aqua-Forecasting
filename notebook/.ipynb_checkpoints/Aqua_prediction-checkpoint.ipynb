# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../datasets/Aqua01/Aqua01.csv')
dataset.head()
# Out:
#                               Time pH (moles/L) DO (mg/L)  \
# 0   Fri, July 26, 2019, 6:33:23 PM            -         0
# 1   Fri, July 26, 2019, 6:46:21 PM         3.83         -
# 2  Mon, July 29, 2019, 12:30:20 PM         3.06         -
# 3   Mon, July 29, 2019, 1:10:14 PM         4.71         -
# 4   Mon, July 29, 2019, 2:00:09 PM         5.19         -
#
#   Water Temperature (℃) Ammonia (mg/L)  Battery (Volts)  Solar (Volts)  \
# 0                     -              -            13.82           3.55
# 1                     -         0.0002            13.49           3.45
# 2                     -              0            13.54           3.54
# 3                     -         0.0017            13.58           3.14
# 4                     -         0.0052            13.22           2.77
#
#    Signal Strength (dB)
# 0                    16
# 1                    19
# 2                    22
# 3                    24
# 4                    23

# %%
dataset.shape
# Out:
# (931, 8)

# %%
dataset.isnull().sum()
# Out:
# Time                     0
# pH (moles/L)             0
# DO (mg/L)                0
# Water Temperature (℃)    0
# Ammonia (mg/L)           0
# Battery (Volts)          0
# Solar (Volts)            0
# Signal Strength (dB)     0
# dtype: int64

# %%
dataset = dataset.replace('-', np.nan)

# %%
dataset.isnull().sum()
# Out:
# Time                       0
# pH (moles/L)               1
# DO (mg/L)                106
# Water Temperature (℃)    126
# Ammonia (mg/L)             1
# Battery (Volts)            0
# Solar (Volts)              0
# Signal Strength (dB)       0
# dtype: int64

# %%
dataset['Time'] = pd.to_datetime(dataset['Time'])

# %%
dataset.head()
# Out:
#                  Time pH (moles/L) DO (mg/L) Water Temperature (℃)  \
# 0 2019-07-26 18:33:23          NaN         0                   NaN
# 1 2019-07-26 18:46:21         3.83       NaN                   NaN
# 2 2019-07-29 12:30:20         3.06       NaN                   NaN
# 3 2019-07-29 13:10:14         4.71       NaN                   NaN
# 4 2019-07-29 14:00:09         5.19       NaN                   NaN
#
#   Ammonia (mg/L)  Battery (Volts)  Solar (Volts)  Signal Strength (dB)
# 0            NaN            13.82           3.55                    16
# 1         0.0002            13.49           3.45                    19
# 2              0            13.54           3.54                    22
# 3         0.0017            13.58           3.14                    24
# 4         0.0052            13.22           2.77                    23

# %%
dataset1 = dataset.fillna(-1)

# %%
dataset1[dataset1.columns[1:4]] = dataset1[dataset1.columns[1:4]].apply(pd.to_numeric)

# %%
dataset1[dataset1.columns[1]].plot(figsize = (20,10), marker = 'o', linestyle = '-')

# %%
dataset1[dataset1.columns[2]].plot(figsize = (20,10), marker = 'o', linestyle = '-')

# %%
dataset1[dataset1.columns[3]].plot(figsize = (20,10), marker = 'o', linestyle = '-')

# %%
dataset.head()
# Out:
#                  Time pH (moles/L) DO (mg/L) Water Temperature (℃)  \
# 0 2019-07-26 18:33:23          NaN         0                   NaN
# 1 2019-07-26 18:46:21         3.83       NaN                   NaN
# 2 2019-07-29 12:30:20         3.06       NaN                   NaN
# 3 2019-07-29 13:10:14         4.71       NaN                   NaN
# 4 2019-07-29 14:00:09         5.19       NaN                   NaN
#
#   Ammonia (mg/L)  Battery (Volts)  Solar (Volts)  Signal Strength (dB)
# 0            NaN            13.82           3.55                    16
# 1         0.0002            13.49           3.45                    19
# 2              0            13.54           3.54                    22
# 3         0.0017            13.58           3.14                    24
# 4         0.0052            13.22           2.77                    23

# %%
dataset = dataset.sort_values(by = ['Time'])

# %%
dataset.head()
# Out:
#                  Time pH (moles/L) DO (mg/L) Water Temperature (℃)  \
# 0 2019-07-26 18:33:23          NaN         0                   NaN
# 1 2019-07-26 18:46:21         3.83       NaN                   NaN
# 2 2019-07-29 12:30:20         3.06       NaN                   NaN
# 3 2019-07-29 13:10:14         4.71       NaN                   NaN
# 4 2019-07-29 14:00:09         5.19       NaN                   NaN
#
#   Ammonia (mg/L)  Battery (Volts)  Solar (Volts)  Signal Strength (dB)
# 0            NaN            13.82           3.55                    16
# 1         0.0002            13.49           3.45                    19
# 2              0            13.54           3.54                    22
# 3         0.0017            13.58           3.14                    24
# 4         0.0052            13.22           2.77                    23

# %%
window_start = dataset.loc[0]['Time']
window_start = window_start.replace(minute = 0, second = 0)
time_end = dataset.loc[dataset.shape[0]-1]['Time']
time_end = time_end.replace(minute = 59, second = 59)

# %%
window_start
# Out:
# Timestamp('2019-07-26 18:00:00')

# %%
window_size = 3599

# %%
import datetime
window_end = window_start + datetime.timedelta(seconds = window_size)

# %%
print('window_start:',window_start,'\nwindow_end:',window_end,'\ntime_end:',time_end)
# Out:
# window_start: 2019-07-26 18:00:00
# window_end: 2019-07-26 18:59:59
# time_end: 2019-11-18 15:59:59

# %%
for window_end <= time_end:
